# %%
import pandas as pd

df = pd.read_json(r"C:\Users\C2D\Downloads\sample_books_400 (1).json")

print(df.to_string())

[
  {
    "Book Title": "Animal Farm #1",
    "Price": 12.25,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Lord of the Flies #2",
    "Price": 5.4,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "To Kill a Mockingbird #3",
    "Price": 19.18,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Great Expectations #4",
    "Price": 8.12,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Crime and Punishment #5",
    "Price": 9.28,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Les Mis\u00e9rables #6",
    "Price": 19.63,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Anna Karenina #7",
    "Price": 14.25,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Brave New World #8",
    "Price": 9.79,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #9",
    "Price": 15.49,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #10",
    "Price": 15.16,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Les Mis\u00e9rables #11",
    "Price": 15.08,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "The Great Gatsby #12",
    "Price": 17.42,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #13",
    "Price": 13.07,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Ulysses #14",
    "Price": 12.05,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #15",
    "Price": 8.5,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Frankenstein #16",
    "Price": 8.43,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Brave New World #17",
    "Price": 17.08,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Don Quixote #18",
    "Price": 16.51,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Brave New World #19",
    "Price": 9.78,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Fahrenheit 451 #20",
    "Price": 8.21,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Fahrenheit 451 #21",
    "Price": 16.39,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "1984 #22",
    "Price": 18.07,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Lord of the Flies #23",
    "Price": 17.92,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Fahrenheit 451 #24",
    "Price": 5.36,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #25",
    "Price": 9.51,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Brave New World #26",
    "Price": 18.23,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #27",
    "Price": 10.75,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Animal Farm #28",
    "Price": 8.26,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Hobbit #29",
    "Price": 19.63,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Les Mis\u00e9rables #30",
    "Price": 9.72,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Brave New World #31",
    "Price": 18.32,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Hobbit #32",
    "Price": 10.81,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "1984 #33",
    "Price": 14.4,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Hamlet #34",
    "Price": 5.01,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #35",
    "Price": 9.31,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Don Quixote #36",
    "Price": 6.54,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Pride and Prejudice #37",
    "Price": 14.27,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Divine Comedy #38",
    "Price": 11.69,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "War and Peace #39",
    "Price": 18.19,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Animal Farm #40",
    "Price": 18.35,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Crime and Punishment #41",
    "Price": 13.05,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Pride and Prejudice #42",
    "Price": 6.23,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Brave New World #43",
    "Price": 8.37,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Ulysses #44",
    "Price": 8.92,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #45",
    "Price": 15.23,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Dracula #46",
    "Price": 9.79,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Les Mis\u00e9rables #47",
    "Price": 8.52,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Odyssey #48",
    "Price": 5.5,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "To Kill a Mockingbird #49",
    "Price": 12.03,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Great Gatsby #50",
    "Price": 16.92,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Great Expectations #51",
    "Price": 13.94,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #52",
    "Price": 11.52,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Don Quixote #53",
    "Price": 19.87,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #54",
    "Price": 15.33,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Hobbit #55",
    "Price": 8.5,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #56",
    "Price": 12.74,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Animal Farm #57",
    "Price": 8.55,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "1984 #58",
    "Price": 11.84,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Les Mis\u00e9rables #59",
    "Price": 9.79,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Great Expectations #60",
    "Price": 11.52,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Crime and Punishment #61",
    "Price": 5.2,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #62",
    "Price": 12.67,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #63",
    "Price": 15.86,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Crime and Punishment #64",
    "Price": 15.14,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Hamlet #65",
    "Price": 7.52,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #66",
    "Price": 6.48,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Jane Eyre #67",
    "Price": 5.4,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Wuthering Heights #68",
    "Price": 13.09,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Great Expectations #69",
    "Price": 13.69,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Animal Farm #70",
    "Price": 19.77,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #71",
    "Price": 17.61,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Hobbit #72",
    "Price": 12.25,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Great Gatsby #73",
    "Price": 13.35,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Moby Dick #74",
    "Price": 9.17,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "To Kill a Mockingbird #75",
    "Price": 6.14,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Divine Comedy #76",
    "Price": 9.3,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Lord of the Flies #77",
    "Price": 11.46,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Great Gatsby #78",
    "Price": 18.91,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "The Odyssey #79",
    "Price": 8.49,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Animal Farm #80",
    "Price": 9.42,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Brave New World #81",
    "Price": 18.44,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Don Quixote #82",
    "Price": 7.35,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Catch-22 #83",
    "Price": 12.13,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Fahrenheit 451 #84",
    "Price": 19.89,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Hobbit #85",
    "Price": 9.34,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "1984 #86",
    "Price": 16.61,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #87",
    "Price": 13.83,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Fahrenheit 451 #88",
    "Price": 12.0,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Divine Comedy #89",
    "Price": 12.67,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #90",
    "Price": 6.8,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Great Gatsby #91",
    "Price": 5.49,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #92",
    "Price": 5.2,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Dracula #93",
    "Price": 15.93,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #94",
    "Price": 8.47,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #95",
    "Price": 16.34,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #96",
    "Price": 18.24,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Animal Farm #97",
    "Price": 9.83,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #98",
    "Price": 5.15,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Jane Eyre #99",
    "Price": 11.4,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Animal Farm #100",
    "Price": 8.54,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Moby Dick #101",
    "Price": 17.96,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Brave New World #102",
    "Price": 15.25,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "War and Peace #103",
    "Price": 5.37,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Great Expectations #104",
    "Price": 18.63,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Odyssey #105",
    "Price": 5.96,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Fahrenheit 451 #106",
    "Price": 10.21,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Frankenstein #107",
    "Price": 13.13,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Ulysses #108",
    "Price": 14.57,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Crime and Punishment #109",
    "Price": 6.45,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Moby Dick #110",
    "Price": 8.18,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "To Kill a Mockingbird #111",
    "Price": 13.82,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Animal Farm #112",
    "Price": 5.9,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "To Kill a Mockingbird #113",
    "Price": 9.84,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Animal Farm #114",
    "Price": 12.11,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Catch-22 #115",
    "Price": 13.91,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Les Mis\u00e9rables #116",
    "Price": 8.82,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Hamlet #117",
    "Price": 19.71,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Anna Karenina #118",
    "Price": 10.63,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Great Gatsby #119",
    "Price": 8.56,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "1984 #120",
    "Price": 15.49,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Frankenstein #121",
    "Price": 18.42,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "To Kill a Mockingbird #122",
    "Price": 9.76,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Fahrenheit 451 #123",
    "Price": 13.58,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Catch-22 #124",
    "Price": 13.55,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "1984 #125",
    "Price": 11.4,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Ulysses #126",
    "Price": 19.22,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #127",
    "Price": 9.49,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Great Expectations #128",
    "Price": 5.76,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Ulysses #129",
    "Price": 18.24,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Divine Comedy #130",
    "Price": 17.77,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #131",
    "Price": 10.02,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Lord of the Flies #132",
    "Price": 9.58,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Brave New World #133",
    "Price": 10.04,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Jane Eyre #134",
    "Price": 10.12,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #135",
    "Price": 18.99,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Hamlet #136",
    "Price": 8.1,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Odyssey #137",
    "Price": 16.51,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Crime and Punishment #138",
    "Price": 8.93,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "War and Peace #139",
    "Price": 13.56,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Fahrenheit 451 #140",
    "Price": 16.26,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #141",
    "Price": 18.2,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Lord of the Flies #142",
    "Price": 19.42,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Odyssey #143",
    "Price": 18.97,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Don Quixote #144",
    "Price": 12.7,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #145",
    "Price": 10.77,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #146",
    "Price": 6.6,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #147",
    "Price": 11.27,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Hobbit #148",
    "Price": 18.18,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Great Expectations #149",
    "Price": 13.9,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "1984 #150",
    "Price": 9.25,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #151",
    "Price": 16.35,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Wuthering Heights #152",
    "Price": 10.78,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Wuthering Heights #153",
    "Price": 5.91,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "To Kill a Mockingbird #154",
    "Price": 5.72,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Catch-22 #155",
    "Price": 18.52,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Moby Dick #156",
    "Price": 12.31,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Odyssey #157",
    "Price": 10.27,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #158",
    "Price": 13.0,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #159",
    "Price": 14.11,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #160",
    "Price": 9.57,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Lord of the Flies #161",
    "Price": 9.76,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Les Mis\u00e9rables #162",
    "Price": 7.35,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Hobbit #163",
    "Price": 19.35,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #164",
    "Price": 8.96,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Divine Comedy #165",
    "Price": 12.99,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Crime and Punishment #166",
    "Price": 7.79,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "War and Peace #167",
    "Price": 6.24,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #168",
    "Price": 14.39,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Odyssey #169",
    "Price": 11.85,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "1984 #170",
    "Price": 14.34,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Great Gatsby #171",
    "Price": 15.59,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #172",
    "Price": 12.79,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Lord of the Flies #173",
    "Price": 10.55,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Wuthering Heights #174",
    "Price": 7.49,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Catch-22 #175",
    "Price": 14.99,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Dracula #176",
    "Price": 13.21,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Don Quixote #177",
    "Price": 7.7,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Dracula #178",
    "Price": 15.18,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "The Hobbit #179",
    "Price": 11.0,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Dracula #180",
    "Price": 10.48,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #181",
    "Price": 16.94,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Dracula #182",
    "Price": 10.32,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Brave New World #183",
    "Price": 18.04,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Moby Dick #184",
    "Price": 19.49,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Frankenstein #185",
    "Price": 9.15,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Don Quixote #186",
    "Price": 11.32,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Hobbit #187",
    "Price": 19.8,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "1984 #188",
    "Price": 11.36,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Great Expectations #189",
    "Price": 10.07,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Odyssey #190",
    "Price": 8.19,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Dracula #191",
    "Price": 18.04,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Wuthering Heights #192",
    "Price": 18.75,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Wuthering Heights #193",
    "Price": 16.48,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Brave New World #194",
    "Price": 10.26,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Frankenstein #195",
    "Price": 18.59,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #196",
    "Price": 6.19,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Jane Eyre #197",
    "Price": 11.57,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Hamlet #198",
    "Price": 7.95,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Ulysses #199",
    "Price": 6.23,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Jane Eyre #200",
    "Price": 15.85,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Wuthering Heights #201",
    "Price": 16.33,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Les Mis\u00e9rables #202",
    "Price": 17.75,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Dracula #203",
    "Price": 17.25,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Catch-22 #204",
    "Price": 18.26,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Frankenstein #205",
    "Price": 12.09,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Moby Dick #206",
    "Price": 11.75,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Hobbit #207",
    "Price": 5.98,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Don Quixote #208",
    "Price": 6.34,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Animal Farm #209",
    "Price": 6.76,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Les Mis\u00e9rables #210",
    "Price": 14.49,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "1984 #211",
    "Price": 17.32,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Divine Comedy #212",
    "Price": 7.3,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Animal Farm #213",
    "Price": 15.44,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Great Expectations #214",
    "Price": 9.36,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #215",
    "Price": 5.56,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "1984 #216",
    "Price": 19.77,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Dracula #217",
    "Price": 8.49,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Catch-22 #218",
    "Price": 14.57,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "To Kill a Mockingbird #219",
    "Price": 7.63,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #220",
    "Price": 15.71,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "The Divine Comedy #221",
    "Price": 10.66,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Brave New World #222",
    "Price": 14.15,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Crime and Punishment #223",
    "Price": 19.94,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Les Mis\u00e9rables #224",
    "Price": 17.02,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Don Quixote #225",
    "Price": 19.5,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #226",
    "Price": 13.71,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #227",
    "Price": 10.21,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Divine Comedy #228",
    "Price": 15.04,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Frankenstein #229",
    "Price": 18.4,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Les Mis\u00e9rables #230",
    "Price": 15.49,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Jane Eyre #231",
    "Price": 16.22,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Lord of the Flies #232",
    "Price": 16.5,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Animal Farm #233",
    "Price": 11.19,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Brave New World #234",
    "Price": 15.02,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "War and Peace #235",
    "Price": 18.61,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #236",
    "Price": 13.03,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Animal Farm #237",
    "Price": 11.14,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "The Hobbit #238",
    "Price": 12.93,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Moby Dick #239",
    "Price": 16.13,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Fahrenheit 451 #240",
    "Price": 5.95,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Pride and Prejudice #241",
    "Price": 13.98,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Great Gatsby #242",
    "Price": 16.68,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "The Great Gatsby #243",
    "Price": 13.28,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Jane Eyre #244",
    "Price": 8.15,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Moby Dick #245",
    "Price": 6.08,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Moby Dick #246",
    "Price": 8.85,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Pride and Prejudice #247",
    "Price": 18.71,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #248",
    "Price": 16.34,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Great Gatsby #249",
    "Price": 12.64,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Crime and Punishment #250",
    "Price": 12.07,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Great Expectations #251",
    "Price": 16.18,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "To Kill a Mockingbird #252",
    "Price": 14.7,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "The Hobbit #253",
    "Price": 6.06,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "War and Peace #254",
    "Price": 11.64,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Don Quixote #255",
    "Price": 15.53,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Les Mis\u00e9rables #256",
    "Price": 9.87,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Divine Comedy #257",
    "Price": 13.87,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "To Kill a Mockingbird #258",
    "Price": 11.47,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Hamlet #259",
    "Price": 8.32,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #260",
    "Price": 5.58,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "1984 #261",
    "Price": 11.65,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "War and Peace #262",
    "Price": 12.37,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Ulysses #263",
    "Price": 19.49,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Catch-22 #264",
    "Price": 7.99,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Crime and Punishment #265",
    "Price": 19.52,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Hamlet #266",
    "Price": 13.74,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Pride and Prejudice #267",
    "Price": 7.57,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Jane Eyre #268",
    "Price": 13.37,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Don Quixote #269",
    "Price": 8.51,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Catch-22 #270",
    "Price": 8.81,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Lord of the Flies #271",
    "Price": 14.56,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Divine Comedy #272",
    "Price": 6.29,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #273",
    "Price": 6.75,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Moby Dick #274",
    "Price": 11.37,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "1984 #275",
    "Price": 8.85,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "War and Peace #276",
    "Price": 7.64,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Odyssey #277",
    "Price": 11.14,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Lord of the Flies #278",
    "Price": 13.53,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Jane Eyre #279",
    "Price": 5.19,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Les Mis\u00e9rables #280",
    "Price": 15.64,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "1984 #281",
    "Price": 11.81,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Divine Comedy #282",
    "Price": 19.6,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "The Odyssey #283",
    "Price": 15.5,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Great Expectations #284",
    "Price": 16.98,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Pride and Prejudice #285",
    "Price": 5.14,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Hobbit #286",
    "Price": 11.23,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Odyssey #287",
    "Price": 7.06,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Great Expectations #288",
    "Price": 12.43,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #289",
    "Price": 13.01,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #290",
    "Price": 6.76,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Pride and Prejudice #291",
    "Price": 12.38,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "To Kill a Mockingbird #292",
    "Price": 19.55,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "The Great Gatsby #293",
    "Price": 10.85,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #294",
    "Price": 12.41,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Divine Comedy #295",
    "Price": 17.11,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #296",
    "Price": 11.51,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Jane Eyre #297",
    "Price": 17.07,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #298",
    "Price": 5.43,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Pride and Prejudice #299",
    "Price": 16.54,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Odyssey #300",
    "Price": 16.71,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Ulysses #301",
    "Price": 9.44,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Fahrenheit 451 #302",
    "Price": 10.83,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Ulysses #303",
    "Price": 16.25,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Don Quixote #304",
    "Price": 15.3,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Crime and Punishment #305",
    "Price": 5.56,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Anna Karenina #306",
    "Price": 8.02,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Anna Karenina #307",
    "Price": 16.2,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Frankenstein #308",
    "Price": 6.31,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Animal Farm #309",
    "Price": 13.41,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "To Kill a Mockingbird #310",
    "Price": 9.02,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Pride and Prejudice #311",
    "Price": 6.61,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #312",
    "Price": 13.47,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Odyssey #313",
    "Price": 7.24,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Hobbit #314",
    "Price": 8.22,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Brave New World #315",
    "Price": 16.52,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Great Expectations #316",
    "Price": 13.52,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Crime and Punishment #317",
    "Price": 18.8,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Frankenstein #318",
    "Price": 13.39,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Brave New World #319",
    "Price": 18.79,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Animal Farm #320",
    "Price": 10.96,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Jane Eyre #321",
    "Price": 11.67,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Don Quixote #322",
    "Price": 8.93,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "War and Peace #323",
    "Price": 19.23,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Dracula #324",
    "Price": 6.46,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Lord of the Flies #325",
    "Price": 14.57,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Crime and Punishment #326",
    "Price": 10.2,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Catch-22 #327",
    "Price": 9.06,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Wuthering Heights #328",
    "Price": 12.24,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Pride and Prejudice #329",
    "Price": 11.12,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Ulysses #330",
    "Price": 13.33,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "To Kill a Mockingbird #331",
    "Price": 14.7,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #332",
    "Price": 14.3,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Crime and Punishment #333",
    "Price": 6.84,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "War and Peace #334",
    "Price": 13.87,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Great Expectations #335",
    "Price": 12.28,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Wuthering Heights #336",
    "Price": 19.73,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "To Kill a Mockingbird #337",
    "Price": 11.75,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Ulysses #338",
    "Price": 19.77,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "The Great Gatsby #339",
    "Price": 11.74,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Crime and Punishment #340",
    "Price": 8.83,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Jane Eyre #341",
    "Price": 5.18,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Les Mis\u00e9rables #342",
    "Price": 12.03,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Odyssey #343",
    "Price": 7.17,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Wuthering Heights #344",
    "Price": 11.81,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "War and Peace #345",
    "Price": 19.56,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "The Hobbit #346",
    "Price": 16.83,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Crime and Punishment #347",
    "Price": 15.83,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #348",
    "Price": 18.46,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Divine Comedy #349",
    "Price": 13.76,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Moby Dick #350",
    "Price": 6.43,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Ulysses #351",
    "Price": 8.26,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Fahrenheit 451 #352",
    "Price": 10.32,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Ulysses #353",
    "Price": 6.89,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "The Great Gatsby #354",
    "Price": 16.91,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Jane Eyre #355",
    "Price": 12.33,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Fahrenheit 451 #356",
    "Price": 10.49,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Hamlet #357",
    "Price": 6.46,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Pride and Prejudice #358",
    "Price": 13.36,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Crime and Punishment #359",
    "Price": 13.52,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Anna Karenina #360",
    "Price": 17.16,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Crime and Punishment #361",
    "Price": 16.49,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Les Mis\u00e9rables #362",
    "Price": 10.1,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Moby Dick #363",
    "Price": 10.58,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Divine Comedy #364",
    "Price": 12.07,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Ulysses #365",
    "Price": 8.82,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Don Quixote #366",
    "Price": 17.69,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "Ulysses #367",
    "Price": 19.74,
    "Availability": "In stock",
    "Rating": 4
  },
  {
    "Book Title": "War and Peace #368",
    "Price": 9.48,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Wuthering Heights #369",
    "Price": 10.36,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #370",
    "Price": 17.69,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Divine Comedy #371",
    "Price": 19.88,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Les Mis\u00e9rables #372",
    "Price": 10.86,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "The Divine Comedy #373",
    "Price": 6.3,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Ulysses #374",
    "Price": 5.79,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "Animal Farm #375",
    "Price": 9.83,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Lord of the Flies #376",
    "Price": 11.68,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Wuthering Heights #377",
    "Price": 14.21,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Don Quixote #378",
    "Price": 12.45,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "War and Peace #379",
    "Price": 9.55,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "To Kill a Mockingbird #380",
    "Price": 16.92,
    "Availability": "Out of stock",
    "Rating": 4
  },
  {
    "Book Title": "Anna Karenina #381",
    "Price": 17.38,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Pride and Prejudice #382",
    "Price": 14.11,
    "Availability": "Out of stock",
    "Rating": 3
  },
  {
    "Book Title": "Brave New World #383",
    "Price": 11.43,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Moby Dick #384",
    "Price": 13.14,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "The Odyssey #385",
    "Price": 6.08,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "Lord of the Flies #386",
    "Price": 19.17,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Fahrenheit 451 #387",
    "Price": 18.02,
    "Availability": "In stock",
    "Rating": 5
  },
  {
    "Book Title": "To Kill a Mockingbird #388",
    "Price": 12.29,
    "Availability": "In stock",
    "Rating": 2
  },
  {
    "Book Title": "Hamlet #389",
    "Price": 18.09,
    "Availability": "In stock",
    "Rating": 3
  },
  {
    "Book Title": "Crime and Punishment #390",
    "Price": 19.0,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Hobbit #391",
    "Price": 17.43,
    "Availability": "Out of stock",
    "Rating": 1
  },
  {
    "Book Title": "The Odyssey #392",
    "Price": 12.74,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Ulysses #393",
    "Price": 16.41,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Catch-22 #394",
    "Price": 14.87,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "Crime and Punishment #395",
    "Price": 12.58,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "The Great Gatsby #396",
    "Price": 8.97,
    "Availability": "In stock",
    "Rating": 1
  },
  {
    "Book Title": "Dracula #397",
    "Price": 9.7,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Anna Karenina #398",
    "Price": 9.37,
    "Availability": "Out of stock",
    "Rating": 2
  },
  {
    "Book Title": "Jane Eyre #399",
    "Price": 10.09,
    "Availability": "Out of stock",
    "Rating": 5
  },
  {
    "Book Title": "1984 #400",
    "Price": 14.61,
    "Availability": "Out of stock",
    "Rating": 3
  }
]
# Out:
#                      Book Title  Price  Availability  Rating
# 0                Animal Farm #1  12.25      In stock       4
# 1          Lord of the Flies #2   5.40      In stock       5
# 2      To Kill a Mockingbird #3  19.18      In stock       4
# 3         Great Expectations #4   8.12      In stock       3
# 4       Crime and Punishment #5   9.28  Out of stock       4
# 5             Les Misérables #6  19.63      In stock       5
# 6              Anna Karenina #7  14.25      In stock       1
# 7            Brave New World #8   9.79  Out of stock       2
# 8                    Ulysses #9  15.49  Out of stock       3
# 9       Pride and Prejudice #10  15.16      In stock       5
# 10           Les Misérables #11  15.08      In stock       2
# 11         The Great Gatsby #12  17.42  Out of stock       2
# 12                     1984 #13  13.07  Out of stock       5
# 13                  Ulysses #14  12.05  Out of stock       2
# ...
